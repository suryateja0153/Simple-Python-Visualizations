# %%
#Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import Pasco Data
df = pd.read_excel('Combined.xlsx', sheet_name = 'Pasco')

# %%
#Dataframe Moving Average and Daily Cases
df.columns = ['Date', 'Daily_Cases','Moving_Average']

# %%
#Line Graph the Moving Average and Daily Cases by Date
df.plot('Date', ['Daily_Cases','Moving_Average'])
