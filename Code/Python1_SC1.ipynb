# %%
#Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import Data
df1 = pd.read_excel('2018 Data.xlsx')

# %%
#Scatter-Plot on Median Household Income and Percentage of Population with Insurance
df1.plot('Median Family Income', 'Perc with health Insurance', kind = 'scatter', s =156, c='green', marker=(5, 1))
